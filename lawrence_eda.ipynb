# %%
import torch
from pathlib import Path
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
PATH = Path("./data")

# %%
anime = pd.read_csv(PATH/"anime.csv")

# %%
anime = anime.reset_index()

# %%
anime.query("Name == 'Shingeki no Kyojin'")
# Out:
#       index  MAL_ID                Name Score  \
# 7449   7449   16498  Shingeki no Kyojin  8.48
#
#                                                  Genres     English name  \
# 7449  Action, Military, Mystery, Super Power, Drama,...  Attack on Titan
#
#      Japanese name Type Episodes                        Aired  ...  Score-10  \
# 7449         進撃の巨人   TV       25  Apr 7, 2013 to Sep 29, 2013  ...  470882.0
#
#        Score-9   Score-8   Score-7  Score-6  Score-5  Score-4 Score-3  \
# 7449  514879.0  459113.0  220228.0  70768.0  31141.0  11805.0  4637.0
#
#       Score-2  Score-1
# 7449   2707.0   4939.0
#
# [1 rows x 36 columns]

# %%
item_emb = model_state['item_emb.weight']

# %%
corr = -cosine_similarity(item_emb, item_emb)[16498, :]
closest = corr.argsort()

# %%
closest[:10]
# Out:
# array([16498, 23273, 28171, 25777,  9253,   199, 11757,  7724, 32282,
#         3588])

# %%
anime.loc[anime.MAL_ID.isin(closest[:10]),:].Name.to_list()
# Out:
# ['Sen to Chihiro no Kamikakushi',
#  'Soul Eater',
#  'Shiki',
#  'Steins;Gate',
#  'Sword Art Online',
#  'Shingeki no Kyojin',
#  'Shigatsu wa Kimi no Uso',
#  'Shingeki no Kyojin Season 2',
#  'Shokugeki no Souma',
#  'Shokugeki no Souma: Ni no Sara']

# %%
anime.loc[anime.MAL_ID.isin(closest[:10]),:]
# Out:
#        index  MAL_ID                            Name Score  \
# 176      176     199   Sen to Chihiro no Kamikakushi  8.83
# 3155    3155    3588                      Soul Eater  7.88
# 5132    5132    7724                           Shiki  7.79
# 5683    5683    9253                     Steins;Gate  9.11
# 6614    6614   11757                Sword Art Online  7.25
# 7449    7449   16498              Shingeki no Kyojin  8.48
# 8883    8883   23273         Shigatsu wa Kimi no Uso  8.74
# 9383    9383   25777     Shingeki no Kyojin Season 2  8.45
# 9732    9732   28171              Shokugeki no Souma  8.29
# 11309  11309   32282  Shokugeki no Souma: Ni no Sara  8.21
#
#                                                   Genres  \
# 176                       Adventure, Supernatural, Drama
# 3155      Action, Fantasy, Comedy, Supernatural, Shounen
# 5132    Horror, Mystery, Supernatural, Thriller, Vampire
# 5683                                    Thriller, Sci-Fi
# ...

# %%
corr = -cosine_similarity(item_emb, item_emb)[23273, :]
closest = corr.argsort()

# %%
anime.loc[anime.MAL_ID.isin(closest[:10]),:].Name.to_list()
# Out:
# ['Steins;Gate',
#  'Sakura-sou no Pet na Kanojo',
#  'Shingeki no Kyojin',
#  'Shigatsu wa Kimi no Uso',
#  'Shingeki no Kyojin Season 2',
#  'Shokugeki no Souma',
#  'Shokugeki no Souma: Ni no Sara',
#  'Sakamoto Desu ga?',
#  'Shelter',
#  'Seishun Buta Yarou wa Bunny Girl Senpai no Yume wo Minai']
